# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import glob
import os

# %%
path01="/home/luis11/Documentos/backup_2023/Pasta_fedora01/corrente_escuro/Amostras2022/Amostra1380/Mesa03Terra05/*.txt"
path02="/home/luis11/Documentos/backup_2023/Pasta_fedora01/corrente_escuro/Amostras2022/Amostra1380/Mesa03Terra05/90K.txt"

# df01 = [ pd.read_csv(file, sep=',').values for file in glob.glob(path01)]
df01 = [pd.read_csv(file, sep=',', header=None).values.reshape(501, 5) for file in glob.glob(path01)]
df01
# df02 = pd.concat(df01,
# Out:
# [   0         1             2         3        4     5         6     \
#  0  -5.0 -0.000079  9.910000e+37  11155.05  21508.0 -4.98 -0.000077
#
#             7         8        9     ...  2495      2496          2497  \
#  0  9.910000e+37  11155.65  21508.0  ...  4.98  0.000021  9.910000e+37
#
#         2498     2499  2500      2501          2502      2503     2504
#  0  11461.85  21508.0   5.0  0.000021  9.910000e+37  11462.45  21508.0
#
#  [1 rows x 2505 columns],
#     0         1             2         3        4     5         6     \
#  0  -5.0 -0.000129  9.910000e+37  12058.41  21508.0 -4.98 -0.000126
#
#             7         8        9     ...  2495      2496          2497  \
#  0  9.910000e+37  12058.47  21508.0  ...  4.98  0.000035  9.910000e+37
#
#         2498     2499  2500      2501          2502     2503     2504
#  0  12095.43  21508.0   5.0  0.000036  9.910000e+37  12095.5  21508.0
#
#  [1 rows x 2505 columns],
# ...
