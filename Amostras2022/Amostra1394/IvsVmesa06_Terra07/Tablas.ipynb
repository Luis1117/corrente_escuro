# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import dataframe_image as   dfi

# %%
df = pd.read_csv('LnvsT1394Mesa06Terra07.txt', sep = ',', header=None, names=['coef. ang.(A/V)', 'erro ang.',' Voltagem (V)', 'temperatura (K)', '1 / coef ang (V/A)', 'erro ang / (coef ang)^2', '1 / (coef ang)*5e-8' , '(erro Coef.ang)/(coef ang * 10e-8)', 'ln(1/(coef ang)*5e-8)', 'erro coef/ coef ang','1 / temperatura' ])
df
# Out:
#       coef. ang.(A/V)     erro ang.   Voltagem (V)  temperatura (K)  \
# 0            0.000001  2.020726e-09           -5.0            100.0
# 1            0.000002  2.527351e-08           -5.0            110.0
# 2            0.000004  8.183940e-09           -5.0            120.0
# 3            0.000002  1.367887e-07           -5.0            130.0
# 4            0.000010  5.340490e-09           -5.0            140.0
# ...               ...           ...            ...              ...
# 2116         0.001034  5.643599e-06            5.0            260.0
# 2117         0.001348  7.953000e-06            5.0            270.0
# 2118         0.001581  1.288934e-05            5.0            280.0
# 2119         0.001861  3.872577e-05            5.0            290.0
# 2120         0.003255  7.174732e-04            5.0            300.0
#
#       1 / coef ang (V/A)  erro ang / (coef ang)^2  1 / (coef ang)*5e-8  \
# 0          683200.109312               943.198869             0.034160
# ...

# %%
df02 = df.iloc[[0, 1, 2, 1059, 1061, 2118, 2119, 2120]]
df02
# Out:
#       coef. ang.     erro ang.   Voltagem  temperatura  1 / coef ang   \
# 0       0.000001  2.020726e-09       -5.0        100.0  683200.109312
# 1       0.000002  2.527351e-08       -5.0        110.0  481666.566319
# 2       0.000004  8.183940e-09       -5.0        120.0  258834.339552
# 1059    0.000002  1.567783e-07        0.0        190.0  574065.681553
# 1061    0.000007  5.973291e-07        0.0        210.0  146310.488414
# 2118    0.001581  1.288934e-05        5.0        280.0     632.321093
# 2119    0.001861  3.872577e-05        5.0        290.0     537.222827
# 2120    0.003255  7.174732e-04        5.0        300.0     307.266861
#
#       erro ang / (coef ang)^2  1 / (coef ang)*5e-8  \
# 0                  943.198869             0.034160
# 1                 5863.521625             0.024083
# 2                  548.284827             0.012942
# 1059             51666.519708             0.028703
# 1061             12786.881129             0.007316
# ...

# %%
# dfi.export(df02, 'TabelaLnvsT.png')
# Out:
# [0828/083852.287213:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0828/083852.289561:WARNING:bluez_dbus_manager.cc(247)] Floss manager not present, cannot set Floss enable/disable.
# [0828/083852.607932:INFO:headless_shell.cc(660)] Written to file /tmp/tmpk184c1tq/temp.png.
# [0828/083852.749403:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0828/083852.763627:WARNING:bluez_dbus_manager.cc(247)] Floss manager not present, cannot set Floss enable/disable.
# [0828/083853.042274:INFO:headless_shell.cc(660)] Written to file /tmp/tmpvcogtwot/temp.png.

# %%
'coef ang, erro coef ang, voltagem, Ea(eV), Erro-Ea(eV), Ea(meV), Erro-Ea(meV)'

# %%
df3 = pd.read_csv('Ea1394Mesa#6_Terra07MelhorRes.txt', header=None, sep=',', names=['coef ang(A/V)', 'erro coef ang', 'voltagem(V)', 'Ea(eV)', 'Erro-Ea(eV)', 'Ea(meV)', 'Erro-Ea(meV)'])
df3
# Out:
#      coef ang(A/V)  erro coef ang  voltagem(V)    Ea(eV)  Erro-Ea(eV)  \
# 0      1721.024530      35.306963         -5.0  0.148180     0.003040
# 1      1798.467659      35.544092         -4.9  0.154848     0.003060
# 2      1815.160845      36.772685         -4.8  0.156285     0.003166
# 3      1835.672429      38.859881         -4.7  0.158051     0.003346
# 4      1857.579103      39.833431         -4.6  0.159938     0.003430
# ..             ...            ...          ...       ...          ...
# 96     2080.290474      48.022441          4.6  0.179113     0.004135
# 97     2067.879941      45.823548          4.7  0.178044     0.003945
# 98     2052.244569      44.682660          4.8  0.176698     0.003847
# 99     2035.233620      44.405391          4.9  0.175234     0.003823
# 100    2022.969181      44.052999          5.0  0.174178     0.003793
#
#         Ea(meV)  Erro-Ea(meV)
# 0    148.180212      3.039930
# 1    154.848065      3.060346
# 2    156.285349      3.166128
# ...

# %%
b = df3.iloc[[0, 1, 2, 49, 50, 51, 98, 99, 100]]
b
# Out:
#      coef ang(A/V)  erro coef ang  voltagem(V)    Ea(eV)  Erro-Ea(eV)  \
# 0      1721.024530      35.306963         -5.0  0.148180     0.003040
# 1      1798.467659      35.544092         -4.9  0.154848     0.003060
# 2      1815.160845      36.772685         -4.8  0.156285     0.003166
# 49     3612.604186     182.769982         -0.1  0.311045     0.015736
# 50     3682.953887     110.257171          0.0  0.317102     0.009493
# 51     3107.452525      87.038139          0.1  0.267552     0.007494
# 98     2052.244569      44.682660          4.8  0.176698     0.003847
# 99     2035.233620      44.405391          4.9  0.175234     0.003823
# 100    2022.969181      44.052999          5.0  0.174178     0.003793
#
#         Ea(meV)  Erro-Ea(meV)
# 0    148.180212      3.039930
# 1    154.848065      3.060346
# 2    156.285349      3.166128
# 49   311.045220     15.736495
# 50   317.102330      9.493142
# 51   267.551662      7.493984
# 98   176.698257      3.847177
# ...

# %%
dfi.export(b, 'EavsV.png')
# Out:
# [0828/184945.624074:WARNING:sandbox_linux.cc(376)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0828/184945.629104:WARNING:bluez_dbus_manager.cc(247)] Floss manager not present, cannot set Floss enable/disable.
# [0828/184945.934696:INFO:headless_shell.cc(660)] Written to file /tmp/tmpz9tio2oz/temp.png.
